# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
url_conf = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv'

# %%
ts_conf = pd.read_csv(url_conf)

# %%
def frame_args(duration):
    return {
            "frame": {"duration": duration},
            "mode": "immediate",
            "fromcurrent": True,
            "transition": {"duration": duration, "easing": "linear"},
        }

# %%
buttons = [{
                "buttons": [
                    {
                        "args": [None],
                        "label": "&#9654;", # play symbol
                        "method": "animate",
                    },
                    {
                        "args": [[None], frame_args(0)],
                        "label": "&#9724;", # pause symbol
                        "method": "animate",
                    },
                ],
                "direction": "left",
                "pad": {"r": 10, "t": 70},
                "type": "buttons",
                "x": 0.1,
                "y": 0,
            
            }]

# %%
frames = []

for day in ts_conf.columns[4:]:
    
    df1 = ts_conf.loc[ts_conf[day] != 0, :]
    
    data = go.Scattergeo(marker = dict(color = 'darkorange', sizemode = 'area', size = 7,line = dict(
                width=1,color='black')), opacity=0.85,
        lon = df1['Long'],
        lat = df1['Lat'])
    
    frames.append(go.Frame(data=data, name=day))

sliders = [
            {
                "pad": {"b": 10, "t": 60},
                "len": 0.9,
                "x": 0.1,
                "y": 0,
                "steps": [
                    {
                        "args": [[f.name]],
                        "label": str(f.name),
                        "method": "animate",
                    }
                    for f in frames
                ],
            }
        ]

fig_dict ={
    
    "data": [go.Scattergeo()],
    
    "layout": go.Layout(updatemenus=buttons, autosize=False,
                sliders = sliders, width=1000, height=900,
    margin=dict(l=0, r=50),),
    
    'frames':frames
    
}

fig = go.Figure(fig_dict)

fig.update_geos(
    projection_type="equirectangular",
    landcolor="white",
    oceancolor="MidnightBlue",
    showocean=True,
    lakecolor="LightBlue"
)

fig.show()
# Out:
# <div>
#
#
#             <div id="c75a3f90-e001-406d-b288-b254115f0c60" class="plotly-graph-div" style="height:900px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c75a3f90-e001-406d-b288-b254115f0c60")) {
#                     Plotly.newPlot(
#                         'c75a3f90-e001-406d-b288-b254115f0c60',
#                         [{"type": "scattergeo"}],
#                         {"autosize": false, "geo": {"lakecolor": "LightBlue", "landcolor": "white", "oceancolor": "MidnightBlue", "projection": {"type": "equirectangular"}, "showocean": true}, "height": 900, "margin": {"l": 0, "r": 50}, "sliders": [{"len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["1/22/20"]], "label": "1/22/20", "method": "animate"}, {"args": [["1/23/20"]], "label": "1/23/20", "method": "animate"}, {"args": [["1/24/20"]], "label": "1/24/20", "method": "animate"}, {"args": [["1/25/20"]], "label": "1/25/20", "method": "animate"}, {"args": [["1/26/20"]], "label": "1/26/20", "method": "animate"}, {"args": [["1/27/20"]], "label": "1/27/20", "method": "animate"}, {"args": [["1/28/20"]], "label": "1/28/20", "method": "animate"}, {"args": [["1/29/20"]], "label": "1/29/20", "method": "animate"}, {"args": [["1/30/20"]], "label": "1/30/20", "method": "animate"}, {"args": [["1/31/20"]], "label": "1/31/20", "method": "animate"}, {"args": [["2/1/20"]], "label": "2/1/20", "method": "animate"}, {"args": [["2/2/20"]], "label": "2/2/20", "method": "animate"}, {"args": [["2/3/20"]], "label": "2/3/20", "method": "animate"}, {"args": [["2/4/20"]], "label": "2/4/20", "method": "animate"}, {"args": [["2/5/20"]], "label": "2/5/20", "method": "animate"}, {"args": [["2/6/20"]], "label": "2/6/20", "method": "animate"}, {"args": [["2/7/20"]], "label": "2/7/20", "method": "animate"}, {"args": [["2/8/20"]], "label": "2/8/20", "method": "animate"}, {"args": [["2/9/20"]], "label": "2/9/20", "method": "animate"}, {"args": [["2/10/20"]], "label": "2/10/20", "method": "animate"}, {"args": [["2/11/20"]], "label": "2/11/20", "method": "animate"}, {"args": [["2/12/20"]], "label": "2/12/20", "method": "animate"}, {"args": [["2/13/20"]], "label": "2/13/20", "method": "animate"}, {"args": [["2/14/20"]], "label": "2/14/20", "method": "animate"}, {"args": [["2/15/20"]], "label": "2/15/20", "method": "animate"}, {"args": [["2/16/20"]], "label": "2/16/20", "method": "animate"}, {"args": [["2/17/20"]], "label": "2/17/20", "method": "animate"}, {"args": [["2/18/20"]], "label": "2/18/20", "method": "animate"}, {"args": [["2/19/20"]], "label": "2/19/20", "method": "animate"}, {"args": [["2/20/20"]], "label": "2/20/20", "method": "animate"}, {"args": [["2/21/20"]], "label": "2/21/20", "method": "animate"}, {"args": [["2/22/20"]], "label": "2/22/20", "method": "animate"}, {"args": [["2/23/20"]], "label": "2/23/20", "method": "animate"}, {"args": [["2/24/20"]], "label": "2/24/20", "method": "animate"}, {"args": [["2/25/20"]], "label": "2/25/20", "method": "animate"}, {"args": [["2/26/20"]], "label": "2/26/20", "method": "animate"}, {"args": [["2/27/20"]], "label": "2/27/20", "method": "animate"}, {"args": [["2/28/20"]], "label": "2/28/20", "method": "animate"}, {"args": [["2/29/20"]], "label": "2/29/20", "method": "animate"}, {"args": [["3/1/20"]], "label": "3/1/20", "method": "animate"}, {"args": [["3/2/20"]], "label": "3/2/20", "method": "animate"}, {"args": [["3/3/20"]], "label": "3/3/20", "method": "animate"}, {"args": [["3/4/20"]], "label": "3/4/20", "method": "animate"}, {"args": [["3/5/20"]], "label": "3/5/20", "method": "animate"}, {"args": [["3/6/20"]], "label": "3/6/20", "method": "animate"}, {"args": [["3/7/20"]], "label": "3/7/20", "method": "animate"}, {"args": [["3/8/20"]], "label": "3/8/20", "method": "animate"}, {"args": [["3/9/20"]], "label": "3/9/20", "method": "animate"}, {"args": [["3/10/20"]], "label": "3/10/20", "method": "animate"}, {"args": [["3/11/20"]], "label": "3/11/20", "method": "animate"}, {"args": [["3/12/20"]], "label": "3/12/20", "method": "animate"}, {"args": [["3/13/20"]], "label": "3/13/20", "method": "animate"}, {"args": [["3/14/20"]], "label": "3/14/20", "method": "animate"}], "x": 0.1, "y": 0}], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5E ...
